# %%
# Packages for EDA 
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd 
import numpy as np 

import warnings 
warnings.filterwarnings("ignore")

# %%
# from sklearn.metrics import classification_report 
# # import joblib # 파이프제작 파이프라인

# # Packages options 
# sns.set(rc={'figure.figsize': [14, 7]}, font_scale=1.2) # Standard figure size for all 
# np.seterr(divide='ignore', invalid='ignore', over='ignore') ;

# import warnings 
# warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./csv/test_swmotorcycle_False.csv')
df.head(3)
# Out:
#    OwnerAge  Gender                                            Area  \
# 0         0    Male  Central parts of Sweden's three largest cities
# 1         4    Male     Lesser towns except Gotland; Northern towns
# 2         5  Female     Lesser towns except Gotland; Northern towns
#
#         RiskClass  VehAge BonusClass  Exposure  ClaimNb  ClaimAmount
# 0  EV ratio 13-15      12        BM1  0.175342        0            0
# 1  EV ratio 20-24       9        BM1  0.000000        0            0
# 2   EV ratio 9-12      18        BM1  0.454795        0            0

# %%
df.head(200)
# Out:
#      OwnerAge  Gender                                               Area  \
# 0           0    Male     Central parts of Sweden's three largest cities
# 1           4    Male        Lesser towns except Gotland; Northern towns
# 2           5  Female        Lesser towns except Gotland; Northern towns
# 3           5  Female  Small towns; countryside except Gotland; North...
# 4           6  Female                       Suburbs; middle-sized cities
# ..        ...     ...                                                ...
# 195        17  Female  Small towns; countryside except Gotland; North...
# 196        17  Female  Small towns; countryside except Gotland; North...
# 197        17  Female  Small towns; countryside except Gotland; North...
# 198        17  Female  Small towns; countryside except Gotland; North...
# 199        17  Female  Small towns; countryside except Gotland; North...
#
#           RiskClass  VehAge BonusClass  Exposure  ClaimNb  ClaimAmount
# ...

# %%
df["Frequency"]=df["ClaimNb"]/df["Exposure"]

# %%
df["Frequency"].value_counts(ascending=True)
# Out:
# 3.173918        1
# 0.630397        1
# 0.131248        1
# 0.623932        1
# 0.233525        1
#             ...
# 2.016576        7
# 2.005495        7
# 1.994535        9
# 1.000000       24
# 0.000000    61808
# Name: Frequency, Length: 445, dtype: int64

# %%
df.head()
# Out:
#    OwnerAge  Gender                                               Area  \
# 0         0    Male     Central parts of Sweden's three largest cities
# 1         4    Male        Lesser towns except Gotland; Northern towns
# 2         5  Female        Lesser towns except Gotland; Northern towns
# 3         5  Female  Small towns; countryside except Gotland; North...
# 4         6  Female                       Suburbs; middle-sized cities
#
#         RiskClass  VehAge BonusClass  Exposure  ClaimNb  ClaimAmount  \
# 0  EV ratio 13-15      12        BM1  0.175342        0            0
# 1  EV ratio 20-24       9        BM1  0.000000        0            0
# 2   EV ratio 9-12      18        BM1  0.454795        0            0
# 3     EV ratio <5      25        BM1  0.172603        0            0
# 4     EV ratio <5      26        BM1  0.180822        0            0
#
#    Frequency
# 0        0.0
# 1        NaN
# 2        0.0
# 3        0.0
# 4        0.0

# %%
df.isna().sum()
# Out:
# OwnerAge          0
# Gender            0
# Area              0
# RiskClass         0
# VehAge            0
# BonusClass        0
# Exposure          0
# ClaimNb           0
# ClaimAmount       0
# Frequency      2070
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# OwnerAge       0
# Gender         0
# Area           0
# RiskClass      0
# VehAge         0
# BonusClass     0
# Exposure       0
# ClaimNb        0
# ClaimAmount    0
# Frequency      0
# dtype: int64

# %%
df.describe()
# Out:
#            OwnerAge        VehAge      Exposure       ClaimNb    ClaimAmount  \
# count  62478.000000  62478.000000  62478.000000  62478.000000   62478.000000
# mean      42.537421     12.556884      1.044157      0.011156     272.765133
# std       12.961756      9.685455      1.315685      0.109069    4771.582594
# min        0.000000      0.000000      0.000000      0.000000       0.000000
# 25%       31.000000      5.000000      0.490411      0.000000       0.000000
# 50%       44.000000     12.000000      0.893151      0.000000       0.000000
# 75%       52.000000     16.000000      1.000000      0.000000       0.000000
# max       92.000000     99.000000     31.339730      2.000000  365347.000000
#
#        Frequency
# count    62478.0
# mean         inf
# std          NaN
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          inf

# %%
df = df.replace([np.inf, -np.inf], np.nan)

# %%
df.dropna()
# Out:
#        OwnerAge  Gender                                               Area  \
# 0             0    Male     Central parts of Sweden's three largest cities
# 2             5  Female        Lesser towns except Gotland; Northern towns
# 3             5  Female  Small towns; countryside except Gotland; North...
# 4             6  Female                       Suburbs; middle-sized cities
# 5             9  Female        Lesser towns except Gotland; Northern towns
# ...         ...     ...                                                ...
# 64542        85    Male  Small towns; countryside except Gotland; North...
# 64543        86    Male  Small towns; countryside except Gotland; North...
# 64544        86    Male  Small towns; countryside except Gotland; North...
# 64545        87    Male  Small towns; countryside except Gotland; North...
# 64547        92    Male                       Suburbs; middle-sized cities
#
# ...

# %%
df.isna().sum()
# Out:
# OwnerAge       0
# Gender         0
# Area           0
# RiskClass      0
# VehAge         0
# BonusClass     0
# Exposure       0
# ClaimNb        0
# ClaimAmount    0
# Frequency      4
# dtype: int64

# %%
df.describe()
# Out:
#            OwnerAge        VehAge      Exposure       ClaimNb    ClaimAmount  \
# count  62478.000000  62478.000000  62478.000000  62478.000000   62478.000000
# mean      42.537421     12.556884      1.044157      0.011156     272.765133
# std       12.961756      9.685455      1.315685      0.109069    4771.582594
# min        0.000000      0.000000      0.000000      0.000000       0.000000
# 25%       31.000000      5.000000      0.490411      0.000000       0.000000
# 50%       44.000000     12.000000      0.893151      0.000000       0.000000
# 75%       52.000000     16.000000      1.000000      0.000000       0.000000
# max       92.000000     99.000000     31.339730      2.000000  365347.000000
#
#           Frequency
# count  62474.000000
# mean       0.028211
# std        0.945478
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      182.515057

# %%
df['Area'].value_counts()
# Out:
# Small towns; countryside except Gotland; Northern towns    24203
# Lesser towns except Gotland; Northern towns                12302
# Suburbs; middle-sized cities                               11403
# Central parts of Sweden's three largest cities              8212
# Northern countryside                                        3717
# Northern towns                                              2274
# Gotland (Sweden's largest island)                            367
# Name: Area, dtype: int64

# %%
m = {
    "Small towns; countryside except Gotland; Northern towns": "Small towns",
    "Lesser towns except Gotland; Northern towns": "Lesser towns",
    "Suburbs; middle-sized cities": "Middle towns",
    "Central parts of Sweden's three largest cities" : "Largest towns",
    "Northern countryside" : "Northern countryside",
    "Northern towns" : "Northern towns",
    "Gotland (Sweden's largest island)" : "Island"
}

df['Area'] = df['Area'].map(m)

# %%
df['Area'].value_counts()
# Out:
# Small towns             24203
# Lesser towns            12302
# Middle towns            11403
# Largest towns            8212
# Northern countryside     3717
# Northern towns           2274
# Island                    367
# Name: Area, dtype: int64

# %%
df['ClaimNb'].value_counts()
# Out:
# 0    61808
# 1      643
# 2       27
# Name: ClaimNb, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62478 entries, 0 to 64547
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OwnerAge     62478 non-null  int64
#  1   Gender       62478 non-null  object
#  2   Area         62478 non-null  object
#  3   RiskClass    62478 non-null  object
#  4   VehAge       62478 non-null  int64
#  5   BonusClass   62478 non-null  object
#  6   Exposure     62478 non-null  float64
#  7   ClaimNb      62478 non-null  int64
#  8   ClaimAmount  62478 non-null  int64
#  9   Frequency    62474 non-null  float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 5.2+ MB

# %%
df[(df['VehAge']>=40)].value_counts()
# Out:
# OwnerAge  Gender  Area           RiskClass       VehAge  BonusClass  Exposure  ClaimNb  ClaimAmount  Frequency
# 13        Male    Middle towns   EV ratio 6-8    58      BM1         0.931507  0        0            0.0          1
# 52        Male    Small towns    EV ratio <5     48      BM5         0.986301  0        0            0.0          1
#                                                  46      BM3         1.000000  0        0            0.0          1
#                                                          BM1         1.000000  0        0            0.0          1
#                                                  45      BM2         0.495890  0        0            0.0          1
#                                                                                                                  ..
# 39        Male    Largest towns  EV ratio <5     42      BM7         0.495890  0        0            0.0          1
# ...

# %%
sns.distplot(df['OwnerAge'], hist=False)
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
plt.figure(figsize=(7,7))

plt.title('Gender' , fontsize=20)
plt.pie(df['Gender'].value_counts(), labels=df['Gender'].value_counts().index,autopct='%.2f', colors = ['lightblue', 'tomato'])

plt.show()

# %%
sns.countplot(x=df['Area'])
# Out:
# <AxesSubplot: xlabel='Area', ylabel='count'>

# %%
sns.countplot(x=df['RiskClass'])
# Out:
# <AxesSubplot: xlabel='RiskClass', ylabel='count'>

# %%
sns.distplot(df['VehAge'], hist=False)
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
sns.distplot(df['Exposure'], hist=False)
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
sns.distplot(df['ClaimNb'], hist=False)
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
sns.countplot(x=df['BonusClass'])
# Out:
# <AxesSubplot: xlabel='BonusClass', ylabel='count'>

# %%
sns.distplot(df['Frequency'], hist=False)
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
sns.boxplot(data=df, order=['OwnerAge', 'VehAge', 'Exposure'])
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(data=df, order=['Frequency'])
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(data=df, order=['ClaimAmount'])
# Out:
# <AxesSubplot: >
